# %% [markdown]
# # Peer-graded Assignment: Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# Lets download all dependencies that we need for the project

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     openssl-1.1.1e             |       h516909a_0         2.1 MB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     certifi-2019.11.28         |   py36h9f0ad1d_1         149 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0         conda-forge
#     geopy:           1.21.0-py_0       conda-forge
#     python_abi:      3.6-1_cp36m       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.11.27-0                  --> 2019.11.28-hecc5488_0     conda-forge
#     certifi:         2019.11.28-py36_0             --> 2019.11.28-py36h9f0ad1d_1 conda-forge
#     openssl:         1.1.1d-h7b6447c_3             --> 1.1.1e-h516909a_0         conda-forge
#
#
# Downloading and Extracting Packages
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# openssl-1.1.1e       | 2.1 MB    | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# geopy-1.21.0         | 58 KB     | ##################################### | 100%
# certifi-2019.11.28   | 149 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     branca-0.4.0               |             py_0          26 KB  conda-forge
#     altair-4.0.1               |             py_0         575 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         673 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  4.0.1-py_0 conda-forge
#     branca:  0.4.0-py_0 conda-forge
#     folium:  0.5.0-py_0 conda-forge
#     vincent: 0.4.4-py_1 conda-forge
#
#
# Downloading and Extracting Packages
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# branca-0.4.0         | 26 KB     | ##################################### | 100%
# altair-4.0.1         | 575 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %% [markdown]
# Loading the data.

# %%
# for webscraping import Beautiful Soup 
from bs4 import BeautifulSoup

import xml

# %%
link = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
bsoup = BeautifulSoup(link,'lxml')

# %%
table_post = bsoup.find('table')
fields = table_post.find_all('td')

postcode = []
borough = []
neighbourhood = []

for i in range(0, len(fields), 3):
    postcode.append(fields[i].text.strip()[:3])
    borough.append(fields[i+1].text.strip()[3:])
    neighbourhood.append(fields[i+2].text.strip())
        
df_pc = pd.DataFrame(data=[postcode, borough, neighbourhood]).transpose()
df_pc.columns = ['Postcode', 'Borough', 'Neighbourhood']
df_pc.head()
# Out:
#   Postcode                                       Borough  \
# 0      M1A                                  Not assigned
# 1      M4A  Downtown Toronto(Regent Park / Harbourfront)
# 2      M7A                                  Not assigned
# 3      M1B                                  Not assigned
# 4      M4B    Downtown Toronto(Garden District, Ryerson)
#
#                                       Neighbourhood
# 0                          M3ANorth York(Parkwoods)
# 1  M6ANorth York(Lawrence Manor / Lawrence Heights)
# 2                    M9AEtobicoke(Islington Avenue)
# 3                     M3BNorth York(Don Mills)North
# 4                          M6BNorth York(Glencairn)

# %% [markdown]
# Replacing the Not assigned value with np.nan and drop them from the data

# %%
df_pc['Borough'].replace('Not assigned', np.nan, inplace=True)
df_pc.dropna(subset=['Borough'], inplace=True)

df_pc.head()
# Out:
#    Postcode                                       Borough  \
# 1       M4A  Downtown Toronto(Regent Park / Harbourfront)
# 4       M4B    Downtown Toronto(Garden District, Ryerson)
# 7       M4C              Downtown Toronto(St. James Town)
# 10      M4E                 Downtown Toronto(Berczy Park)
# 13      M4G          Downtown Toronto(Central Bay Street)
#
#                                        Neighbourhood
# 1   M6ANorth York(Lawrence Manor / Lawrence Heights)
# 4                           M6BNorth York(Glencairn)
# 7                        M6CYork(Humewood-Cedarvale)
# 10                      M6EYork(Caledonia-Fairbanks)
# 13                     M6GDowntown Toronto(Christie)

# %%
df_pcn = df_pc.groupby(['Postcode', 'Borough'])['Neighbourhood'].apply(', '.join).reset_index()
df_pcn.columns = ['Postcode', 'Borough', 'Neighbourhood']
df_pcn
# Out:
#    Postcode                                            Borough  \
# 0       M1H                      North York(Hillcrest Village)
# 1       M1J         North York(Fairview / Henry Farm / Oriole)
# 2       M1K                        North York(Bayview Village)
# 3       M1L              North York(York Mills / Silver Hills)
# 4       M1M               North York(Willowdale / Newtonbrook)
# 5       M1N                        North York(Willowdale)South
# 6       M1P                        North York(York Mills West)
# 7       M1R                         North York(Willowdale)West
# 8       M4A       Downtown Toronto(Regent Park / Harbourfront)
# 9       M4B         Downtown Toronto(Garden District, Ryerson)
# 10      M4C                   Downtown Toronto(St. James Town)
# 11      M4E                      Downtown Toronto(Berczy Park)
# 12      M4G               Downtown Toronto(Central Bay Street)
# 13      M4H       Downtown Toronto(Richmond / Adelaide / King)
# 14      M4J  Downtown Toronto(Harbourfront East / Union Sta...
# 15      M4K  Downtown Toronto(Toronto Dominion Centre / Des...
# 16      M4L  Downtown Toronto(Commerce Court / Victoria Hotel)
# 17      M4M     North York(Bedford Park / Lawrence Manor East)
# 18      M4N                          Central Toronto(Roselawn)
# 19      M4P          Central Toronto(Forest Hill North & West)
# 20      M4R  Central Toronto(The Annex / North Midtown / Yo...
# 21      M4S  Downtown Toronto(University of Toronto / Harbord)
# 22      M4T  Downtown Toronto(Kensington Market / Chinatown...
# 23      M4V  Downtown Toronto(CN Tower / King and Spadina /...
# 24      M4W  Downtown TorontoStn A PO Boxes25 The Esplanade...
# 25      M4X  Downtown Toronto(First Canadian Place / Underg...
# 26      M7V  Etobicoke(New Toronto / Mimico South / Humber ...
# 27      M7W                 Etobicoke(Alderwood / Long Branch)
# 28      M7X  Etobicoke(The Kingsway / Montgomery Road / Old...
# 29      M7Y  Etobicoke(Old Mill South / King's Mill Park / ...
# 30      M7Z  Etobicoke(Mimico NW / The Queensway West / Sou...
#
#                                         Neighbourhood
# 0   M3HNorth York(Bathurst Manor / Wilson Heights ...
# 1     M3JNorth York(Northwood Park / York University)
# 2         M3KNorth York(Downsview)East  (CFB Toronto)
# 3                        M3LNorth York(Downsview)West
# 4                     M3MNorth York(Downsview)Central
# 5                   M3NNorth York(Downsview)Northwest
# 6                                     M3PNot assigned
# 7                                     M3RNot assigned
# 8    M6ANorth York(Lawrence Manor / Lawrence Heights)
# 9                            M6BNorth York(Glencairn)
# 10                        M6CYork(Humewood-Cedarvale)
# 11                       M6EYork(Caledonia-Fairbanks)
# 12                      M6GDowntown Toronto(Christie)
# 13     M6HWest Toronto(Dufferin / Dovercourt Village)
# 14         M6JWest Toronto(Little Portugal / Trinity)
# 15  M6KWest Toronto(Brockton / Parkdale Village / ...
# 16  M6LNorth York(North Park / Maple Leaf Park / U...
# 17  M6MYork(Del Ray / Mount Dennis / Keelsdale and...
# 18            M6NYork(Runnymede / The Junction North)
# 19    M6PWest Toronto(High Park / The Junction South)
# 20           M6RWest Toronto(Parkdale / Roncesvalles)
# 21               M6SWest Toronto(Runnymede / Swansea)
# 22                                    M6TNot assigned
# 23                                    M6VNot assigned
# 24                                    M6WNot assigned
# 25                                    M6XNot assigned
# 26  M9VEtobicoke(South Steeles / Silverstone / Hum...
# 27  M9WEtobicokeNorthwest(Clairville / Humberwood ...
# 28                                    M9XNot assigned
# 29                                    M9YNot assigned
# 30                                    M9ZNot assigned

# %% [markdown]
# Uploading geospatial data

# %%
df_geo = pd.read_csv('http://cocl.us/Geospatial_data')
df_geo.columns = ['Postcode', 'Latitude', 'Longitude']

df_pos = pd.merge(df_pcn, df_geo, on=['Postcode'], how='inner')

df_tor = df_pos[['Borough', 'Neighbourhood', 'Postcode', 'Latitude', 'Longitude']].copy()

df_tor.head()
# Out:
#                                       Borough  \
# 0               North York(Hillcrest Village)
# 1  North York(Fairview / Henry Farm / Oriole)
# 2                 North York(Bayview Village)
# 3       North York(York Mills / Silver Hills)
# 4        North York(Willowdale / Newtonbrook)
#
#                                        Neighbourhood Postcode   Latitude  \
# 0  M3HNorth York(Bathurst Manor / Wilson Heights ...      M1H  43.773136
# 1    M3JNorth York(Northwood Park / York University)      M1J  43.744734
# 2        M3KNorth York(Downsview)East  (CFB Toronto)      M1K  43.727929
# 3                       M3LNorth York(Downsview)West      M1L  43.711112
# 4                    M3MNorth York(Downsview)Central      M1M  43.716316
#
#    Longitude
# 0 -79.239476
# 1 -79.239476
# 2 -79.262029
# 3 -79.284577
# 4 -79.239476

# %% [markdown]
# To find the geographical coordinate:

# %%
address = 'Toronto, Canada'
geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of the of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:2: DeprecationWarning: Using Nominatim with the default "geopy/1.21.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   from ipykernel import kernelapp as app
# The geograpical coordinate of the of Toronto are 43.653963, -79.387207.

# %% [markdown]
# creating map

# %%
# creating map of New York using latitude, longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# adding markers to map
for lat, lng, borough, neighborhood in zip(df_tor['Latitude'], df_tor['Longitude'], df_tor['Borough'], df_tor['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=3,
        popup=label,
        color='green',
        fill=True,
        fill_color='#3199cc',
        fill_opacity=0.3,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Exploring toronto neighbourhoods

# %%
CLIENT_ID = 'My Name' # your Foursquare ID
CLIENT_SECRET = 'My Secret' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: My Name
# CLIENT_SECRET:My Secret

# %% [markdown]
# selecting neighbour

# %%
df_t4 = df_tor[df_tor['Borough'].str.contains('Toronto')]

to_data = df_t4.reset_index(drop=True)
to_data
# Out:
#                                               Borough  \
# 0        Downtown Toronto(Regent Park / Harbourfront)
# 1          Downtown Toronto(Garden District, Ryerson)
# 2                    Downtown Toronto(St. James Town)
# 3                       Downtown Toronto(Berczy Park)
# 4                Downtown Toronto(Central Bay Street)
# 5        Downtown Toronto(Richmond / Adelaide / King)
# 6   Downtown Toronto(Harbourfront East / Union Sta...
# 7   Downtown Toronto(Toronto Dominion Centre / Des...
# 8   Downtown Toronto(Commerce Court / Victoria Hotel)
# 9                           Central Toronto(Roselawn)
# 10          Central Toronto(Forest Hill North & West)
# 11  Central Toronto(The Annex / North Midtown / Yo...
# 12  Downtown Toronto(University of Toronto / Harbord)
# 13  Downtown Toronto(Kensington Market / Chinatown...
# 14  Downtown Toronto(CN Tower / King and Spadina /...
# 15  Downtown TorontoStn A PO Boxes25 The Esplanade...
# 16  Downtown Toronto(First Canadian Place / Underg...
#
#                                         Neighbourhood Postcode   Latitude  \
# 0    M6ANorth York(Lawrence Manor / Lawrence Heights)      M4A  43.725882
# 1                            M6BNorth York(Glencairn)      M4B  43.706397
# 2                         M6CYork(Humewood-Cedarvale)      M4C  43.695344
# 3                        M6EYork(Caledonia-Fairbanks)      M4E  43.676357
# 4                       M6GDowntown Toronto(Christie)      M4G  43.709060
# 5      M6HWest Toronto(Dufferin / Dovercourt Village)      M4H  43.705369
# 6          M6JWest Toronto(Little Portugal / Trinity)      M4J  43.685347
# 7   M6KWest Toronto(Brockton / Parkdale Village / ...      M4K  43.679557
# 8   M6LNorth York(North Park / Maple Leaf Park / U...      M4L  43.668999
# 9             M6NYork(Runnymede / The Junction North)      M4N  43.728020
# 10    M6PWest Toronto(High Park / The Junction South)      M4P  43.712751
# 11           M6RWest Toronto(Parkdale / Roncesvalles)      M4R  43.715383
# 12               M6SWest Toronto(Runnymede / Swansea)      M4S  43.704324
# 13                                    M6TNot assigned      M4T  43.689574
# 14                                    M6VNot assigned      M4V  43.686412
# 15                                    M6WNot assigned      M4W  43.679563
# 16                                    M6XNot assigned      M4X  43.667967
#
#     Longitude
# 0  -79.315572
# 1  -79.309937
# 2  -79.318389
# 3  -79.293031
# 4  -79.363452
# 5  -79.349372
# 6  -79.338106
# 7  -79.352188
# 8  -79.315572
# 9  -79.388790
# 10 -79.390197
# 11 -79.405678
# 12 -79.388790
# 13 -79.383160
# 14 -79.400049
# 15 -79.377529
# 16 -79.367675

# %% [markdown]
# Map of toronto neighbour

# %%
map_tohood = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(to_data['Latitude'], to_data['Longitude'], to_data['Borough'], to_data['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=3,
        popup=label,
        color='green',
        fill=True,
        fill_color='#3199cc',
        fill_opacity=0.3,
        parse_html=False).add_to(map_tohood)  
    
map_tohood
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# First neighbourhood

# %%
to_data.loc[0, 'Neighbourhood']
# Out:
# 'M6ANorth York(Lawrence Manor / Lawrence Heights)'

# %%
neighbourhood_latitude = to_data.loc[0, 'Latitude'] # neighbourhood latitude value
neighbourhood_longitude = to_data.loc[0, 'Longitude'] # neighbourhood longitude value

neighbourhood_name = to_data.loc[0, 'Neighbourhood'] # neighbourhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighbourhood_name, 
                                                               neighbourhood_latitude, 
                                                               neighbourhood_longitude))
# Out:
# Latitude and longitude values of M6ANorth York(Lawrence Manor / Lawrence Heights) are 43.725882299999995, -79.31557159999998.

# %%
LIMIT = 100
radius = 500

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighbourhood_latitude, 
    neighbourhood_longitude, 
    radius, 
    LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=My Name&client_secret=My Secret&v=20180605&ll=43.725882299999995,-79.31557159999998&radius=500&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 400,
#   'errorType': 'invalid_auth',
#   'errorDetail': 'Missing access credentials. See https://developer.foursquare.com/docs/api/configuration/authentication for details.',
#   'requestId': '5e7a28b3216785001bf981fc'},
#  'response': {}}

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
